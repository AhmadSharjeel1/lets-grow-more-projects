# %% [markdown]
# <a href="https://colab.research.google.com/github/AhmadSharjeel1/lets-grow-more-projects/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
from google.colab.patches import cv2_imshow
img=cv2.imread('/content/download.jpg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=183x275 at 0x7F7367996090>

# %%
gray_image=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=183x275 at 0x7F736791C750>

# %%
gray_image=255-gray_image
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=183x275 at 0x7F7367921D90>

# %%
blurred=cv2.GaussianBlur(gray_image,(21,21),0)

# %%
inverted_blurred=255-blurred
pencil=cv2.divide(gray_image,inverted_blurred,scale=256.0)
cv2_imshow(pencil)
# Out:
# <PIL.Image.Image image mode=L size=183x275 at 0x7F736689E6D0>

# %%
cv2_imshow(img)
cv2_imshow(pencil)
# Out:
# <PIL.Image.Image image mode=RGB size=183x275 at 0x7F7367926290>
# <PIL.Image.Image image mode=L size=183x275 at 0x7F7367926490>
